# %% [markdown]
# <a href="https://colab.research.google.com/github/Drishtygarg/Davis_Training/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

print(f"Even factors of {num} are:")
for i in range(1, num + 1):
    if num % i == 0 and i % 2 == 0:
        print(i)
# Out:
# Enter a number: 42
# Even factors of 42 are:
# 2
# 6
# 14
# 42

# %%
#write a program to check a number is odd or even
def check_even_odd(num):
    if num % 2 == 0:
        return "Even number"
    else:
        return "Odd number"

# input from user
number = int(input("Enter a number: "))

# function call
result = check_even_odd(number)

# output
print(result)
# Out:
# Enter a number: 45
# Odd number

# %%
#To find out factorial of a number
num = int(input("Enter a number: "))
fact = 1

if num < 0:
    print("Factorial does not exist")
elif num == 0:
    print("Factorial is 1")
else:
    for i in range(1, num + 1):
        fact = fact * i
    print("Factorial is:", fact)
# Out:
# Enter a number: 5
# Factorial is: 120
